# %% [markdown]
# ---
# # **Task 4 - Image to Pencil Sketch with Python**
# ---

# %% [markdown]
# ---
# # **Name : Kaviya Sri A.N**
# ---

# %% [markdown]
# ## **Importing the libraries**

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## **Loading the Image**

# %%
img = cv2.imread("rollsroyce.jpg")
img = cv2.resize(img,(1200,795))
i_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)

# %% [markdown]
# ## **Converting Image to Grayscale**

# %%
from IPython.display import display
greyimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyimg))
# Out:
# <PIL.Image.Image image mode=L size=1200x795 at 0x7F4ED9B384D0>

# %% [markdown]
# ## **Converting Image to Negative**

# %%
invtimg = cv2.bitwise_not(greyimg)
display(Image.fromarray(invtimg))
# Out:
# <PIL.Image.Image image mode=L size=1200x795 at 0x7F4ED8AE9C10>

# %% [markdown]
# ## **Smoothening the Image**

# %%
blurimg = cv2.GaussianBlur(invtimg,(5,5),0,0)
display(Image.fromarray(blurimg))
# Out:
# <PIL.Image.Image image mode=L size=1200x795 at 0x7F4ED8AE9650>

# %% [markdown]
# ## **Creating the Pencil Sketch**

# %%
invtblurimg = 255 - blurimg
sketch = cv2.divide(greyimg,invtblurimg,scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=1200x795 at 0x7F4ED8A6D690>

# %% [markdown]
# ## **Comparing the Original Image with Pencil Sketch**

# %%
display(Image.fromarray(i_rgb))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=1200x795 at 0x7F4ED8A56190>
# <PIL.Image.Image image mode=L size=1200x795 at 0x7F4ED8A6DC90>
